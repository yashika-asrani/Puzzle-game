# %% [markdown]
# # Puzzle game in Python made using Pygame v2.0.1.

# %% [markdown]
# #### Made by:-
#     1. Nimish Mathur
#     2. Rushali Tripathy
#     3. Siddharth
#     4. Siddharth Rajagopalan
#     5. Yashika Asrani

# %% [markdown]
# ## Algorithm

# %% [markdown]
# #### Steps:
#     1. Start
#     2. Import packages - pygame and random
#     3. Initialize pygame module
#     4. Set game window icon to 'icon.png'
#     5. Set game window caption to 'Puzzle'
#     6. Set screen size to 300x300 pixels
#     7. Define various color variables with RGB values - WHITE, GREY, BLACK, BLUE
#     8. Define game font as default system font
#     9. Create a Tile class which has takes x and y coordinates for the tile
#         and a int value as value to print on tile.
#         9.1 Define self.box = pygame.Rect(x, y, 100, 100) - this creates an object
#             of type pygame.Rect with location coordinates as x and y and size of x
#             and y as 100 pixels respectively.
#     10. Create a list of possible tile positions in game window - loc
#     11. Shuffle the list.
#     12. Create an empty list - tiles
#     13. Create another list with values 1-8 - vals.
#     14. For each value in range(8), create an object t of class Tile and pass loc[i][0], loc[i][1]
#         and the loop variable.
#         14.1 Append t to tiles.
#     15. Create empty = loc[8], this assigns the last coord in loc to empty
#     16. Create an empty tile, emp_tile = Tile(empty[0], empty[1], -1)
#     17. Define a function swap(), which swaps two tiles in list 'tiles'
#     18. Define a bool variable, run = True
#     19. Fill game screen with color GREY
#     20. Run a while loop till 'run' is True
#         20.1 Run a for loop to check for events.
#         20.2 If event is QUIT, set 'run' to False. This break the while loop
#         20.3 If event is Click on a non-empty tile, check for the location of the tile with empty tile.
#             20.3.1 If empty tile and non-empty tile are 100 pixels apart and their x or y coordinates are equal.
#     21. If 20.3.1 is True, swap tile with empty tile
#     22. Update pygame display
#     23. End

# %% [markdown]
# ## Flowcharts

# %% [markdown]
# ### Main

# %%
from IPython.display import Image
Image(filename='Flowchart-main.png')

# %% [markdown]
# ### Tile() - Class

# %%
from IPython.display import Image
Image(filename='Flowchart-class.png')

# %%
# Puzzle game made in Pygame v2.0.1
# Made by:-
# Nimish Mathur
# Rushali Tripathy
# Siddharth
# Siddharth Rajagopalan
# Yashika Asrani

# Import packages
import pygame
import random

# Initialize Pygame module
pygame.init()

# Set Screen Icon
icon = pygame.image.load('icon.png')
pygame.display.set_icon(icon)

# Set Game Caption
pygame.display.set_caption("Puzzle")

# Set Screen Size
scr_size = (300, 300)
screen = pygame.display.set_mode(scr_size)

# Colors
WHITE = (255, 255, 255)
GREY = (183, 240, 173)
BLACK = (0, 0, 0)
BLUE = (255, 169, 135)

# Text
font = pygame.font.Font(pygame.font.get_default_font(), 20)

# Create a Tile class


class Tile():
    def __init__(self, x, y, val):
        self.loc_x = x
        self.loc_y = y
        self.val = val
        self.box = pygame.Rect(self.loc_x, self.loc_y, 100, 100)


# Create Tile objects
loc = [[0, 0], [100, 0], [200, 0], [0, 100], [100, 100],
       [200, 100], [0, 200], [100, 200], [200, 200]]
random.shuffle(loc)
tiles = []
vals = [1, 2, 3, 4, 5, 6, 7, 8]
for i in range(8):
    t = Tile(loc[i][0], loc[i][1], vals[i])
    tiles.append(t)

# Create empty tile
empty = loc[8]
emp_tile = Tile(empty[0], empty[1], -1)

# # Swap Tiles


def swap():
    temp = i.box
    i.box = emp_tile.box
    emp_tile.box = temp


# Game Loop
run = True
screen.fill(GREY)
print("\n")
while run:
    win = 0
    # Print Tiles
    for i in range(8):
        pygame.draw.rect(screen, BLUE, tiles[i].box)
        val_font = font.render(str(tiles[i].val), True, BLACK)
        screen.blit(val_font, (tiles[i].box.center))
    pygame.draw.rect(screen, GREY, emp_tile.box)

    # Check for events
    for event in pygame.event.get():
        # Quit game
        if event.type == pygame.QUIT:
            run = False
        # On click
        if event.type == pygame.MOUSEBUTTONDOWN:
            if event.button == 1:
                for i in tiles:
                    if i.box.collidepoint(event.pos):
                        # print(i.box, i.val)
                        if i.box.center[0] == emp_tile.box.center[0] and (i.box.center[1]-emp_tile.box.center[1] == 100 or emp_tile.box.center[1]-i.box.center[1] == 100):
                            if i.box.midtop == emp_tile.box.midbottom:
                                # print("Top swap")
                                swap()
                            elif i.box.midbottom == emp_tile.box.midtop:
                                # print("Bottom swap")
                                swap()
                        elif i.box.center[1] == emp_tile.box.center[1] and (i.box.center[0]-emp_tile.box.center[0] == 100 or emp_tile.box.center[0]-i.box.center[0] == 100):
                            if i.box.left == emp_tile.box.right:
                                # print("Left swap")
                                swap()
                            elif i.box.right == emp_tile.box.left:
                                # print("Right swap")
                                swap()
        pygame.display.flip()
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.9.1)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Output Window

# %%
from IPython.display import Image
Image(filename='PuzzleWindow.png')
